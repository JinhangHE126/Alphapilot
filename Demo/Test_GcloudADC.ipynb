# %%
from langchain_google_vertexai import ChatVertexAI

# 初始化模型
# project ID 建议手动填入，确保指向正确
llm = ChatVertexAI(
    model_name="gemini-1.5-pro-002",
    project="project-f562e3d8-9a41-4b1c-a0f", # 填入你截图顶部的 ID
    location="us-east5" # 或者你启用了 Vertex AI 的其他区域
)

# 测试一下
response = llm.invoke("你好，请问你是谁？")
print(response.content)
# Out:
# /var/folders/vz/zs883bb125v6xmzdr27py7p40000gn/T/ipykernel_42109/3356099952.py:5: DeprecationWarning: Use [`ChatGoogleGenerativeAI`][langchain_google_genai.ChatGoogleGenerativeAI] instead.
#   llm = ChatVertexAI(
# I0422 00:53:21.481469 30801241 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(90, generation: 1)
# I0422 00:53:21.481575 30801241 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(92, generation: 1)
# Retrying langchain_google_vertexai.chat_models._completion_with_retry.<locals>._completion_with_retry_inner in 4 seconds as it raised NotFound: 404 Publisher Model `projects/project-f562e3d8-9a41-4b1c-a0f/locations/us-east5/publishers/google/models/gemini-1.5-pro-002` was not found or your project does not have access to it. Please ensure you are using a valid model version. For more information, see: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/model-versions.
# ...
